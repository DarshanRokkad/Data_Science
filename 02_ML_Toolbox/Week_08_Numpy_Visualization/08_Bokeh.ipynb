# %% [markdown]
# # <font color = 'orange'> Bokeh

# %% [markdown]
# ---

# %%
pip install bokeh
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: bokeh in d:\anconda\lib\site-packages (2.4.3)
# Requirement already satisfied: tornado>=5.1 in d:\anconda\lib\site-packages (from bokeh) (6.1)
# Requirement already satisfied: packaging>=16.8 in d:\anconda\lib\site-packages (from bokeh) (21.3)
# Requirement already satisfied: Jinja2>=2.9 in d:\anconda\lib\site-packages (from bokeh) (2.11.3)
# Requirement already satisfied: typing-extensions>=3.10.0 in d:\anconda\lib\site-packages (from bokeh) (4.3.0)
# Requirement already satisfied: numpy>=1.11.3 in d:\anconda\lib\site-packages (from bokeh) (1.21.5)
# Requirement already satisfied: pillow>=7.1.0 in d:\anconda\lib\site-packages (from bokeh) (9.2.0)
# Requirement already satisfied: PyYAML>=3.10 in d:\anconda\lib\site-packages (from bokeh) (6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anconda\lib\site-packages (from Jinja2>=2.9->bokeh) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\anconda\lib\site-packages (from packaging>=16.8->bokeh) (3.0.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# enables the jupyter notebook to render the graph
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ---

# %%
from bokeh.plotting import figure , output_file , show
from bokeh.sampledata.iris import flowers

flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# gives output in a html file
p = figure(title = 'test flower')
p.xaxis.axis_label = 'petal_length'
p.yaxis.axis_label = 'petal_width'
p.circle(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="8adfa492-2f9e-4865-828c-a8ddb5332441" data-root-id="2069"></div>

# %% [markdown]
# ---

# %%
x = [3,4,5,6,7]
y = [4,5,6,7,4]
output_file("line.html")
p = figure(title = "line graph")
p.line(x,y)
show(p)
# Out:
#   <div class="bk-root" id="aec23d15-75b4-400e-8cbd-63c9a5e84651" data-root-id="1799"></div>

# %% [markdown]
# ---

# %%
x = [3,4,5,6,7]
y = [4,5,6,7,4]
output_file("line.html")
p = figure(title = "line graph")
p.scatter(x,y , size = 20,fill_color = 'red',legend_label = 'this is my data point')
show(p)
# Out:
#   <div class="bk-root" id="1d3c32ec-9f92-4460-9f81-bbb526465dd6" data-root-id="2963"></div>

# %% [markdown]
# ---
