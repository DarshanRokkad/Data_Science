# %% [markdown]
# # <font color = 'orange'> Assignment-19 Solutions

# %% [markdown]
# ---

# %% [markdown]
# ### Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# #### Matplotlib is a python library which is used for data analysics and visualization.
# 1. line plot.
# 2. Scatter plot.
# 3. Bar plot.
# 4. Hist plot.
# 5. Box plot.
# 6. Pie plot.

# %% [markdown]
# ---

# %% [markdown]
# ### Q2: What is a scatter plot? Use the following code to generate data for x and y.
# Using this generated data plot a scatter plot.
#
# #### import numpy as np
# #### np.random.seed(3)
# #### x = 3 + np.random.normal(0, 2, 50)
# #### y = 3 + np.random.normal(0, 2, len(x))
#
# #### Note: Also add title, xlabel, and ylabel to the plot.

# %% [markdown]
# #### Scatter plot is used to display the relationship between two or more continuous variables. It is particularly useful for showing how one variable is affected by another.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
import matplotlib.pyplot as plt 

plt.figure(figsize=(6,4))
plt.scatter(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Scatter plot')
# Out:
# Text(0.5, 1.0, 'Scatter plot')

# %% [markdown]
# ---

# %% [markdown]
# ### Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
#
# Use the following data:
#
# #### import numpy as np
# #### For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and  y = np.array([0, 100, 200, 300, 400, 500])
# #### For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# #### For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# #### For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# #### Subplot() function is used to create a grid of subplots within a single figure or plot. Each subplot is essentially a smaller plot within the larger figure, allowing you to display multiple plots or charts together, making it easier to compare and analyze different aspects of your data.

# %%
plt.subplot(2, 2, 1)
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
plt.plot(x1, y1)
plt.title('Line 1')

plt.subplot(2, 2, 2)
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])
plt.plot(x2, y2)
plt.title('Line 2')

plt.subplot(2, 2, 3)
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])
plt.plot(x3, y3)
plt.title('Line 3')

plt.subplot(2, 2, 4)
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])
plt.plot(x4, y4)
plt.title('Line 4')

# Adjust layout and display the figure
plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
#
# #### import numpy as np
# #### company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# #### profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# #### Bar plot is visualization which used to compare the differenct categorical data.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.figure(figsize=(5,4))
plt.bar(company,profit)
plt.xlabel('Company')
plt.ylabel('Profit')
plt.title('Company v/s Profit')
# Out:
# Text(0.5, 1.0, 'Company v/s Profit')

# %% [markdown]
# ---

# %% [markdown]
# ### Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
#
# #### box1 = np.random.normal(100, 10, 200)
# #### box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# #### A box plot, also known as a box-and-whisker plot, is a graphical representation of the distribution of a dataset. It is used to summarize and visualize key statistical information about a dataset, including the central tendency, spread, and presence of outliers

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
plt.figure(figsize = (2,3))
plt.boxplot(box1)
plt.show()

# %%
plt.figure(figsize = (2,3))
plt.boxplot(box2)
plt.show()

# %% [markdown]
# ---
