# %% [markdown]
# # <font color = 'orange'> Contours

# %% [markdown]
# ---

# %%
import cv2

# %% [markdown]
# ---

# %% [markdown]
# ### <font color='blue'> Original image

# %%
img = cv2.imread('Resources/birds.jpg')

cv2.imshow('original image', img)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# #### Output screenshot:
# ![image-5.png](attachment:image-5.png)

# %%
print(img.shape)
# Out:
# (854, 1280, 3)

# %% [markdown]
# ---

# %% [markdown]
# ### <font color='blue'> Threshold function

# %%
img = cv2.imread('Resources/birds.jpg')

ret, thresh = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY_INV)

cv2.imshow('Threshold_image', thresh)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# #### Output screenshot:
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ---

# %% [markdown]
# ### <font color='blue'> Gray Scale Image

# %%
img = cv2.imread('Resources/birds.jpg')

gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2.imshow('grayscale image', gray_img)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# #### Output screenshot:
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# ---

# %% [markdown]
# ### <font color='blue'> Contours

# %%
img = cv2.imread('Resources/birds.jpg')

# contours are the list of isolated objects in the image
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray_img, 127, 255, cv2.THRESH_BINARY_INV)
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

for cnt in contours:
    print(cv2.contourArea(cnt)) # give the area of the contours
# Out:
# 123.0
# 374.0
# 0.0
# 0.0
# 0.0
# 341.5
# 373.0
# 338.0
# 4.0
# 418.0
# 363.5
# 2.5
# 0.0
# 366.0
# 0.0
# 447.5
# 4.0
# 499.5
# 4.0
# 558.5
# 4.0
# 2.0
# 4.0
# 463.0
# 2.0
# 2.0
# 7.5
# 0.0
# 0.0
# 509.0
# 2.0
# 2.0
# 298.5
# 719.0
# 2.0
# 2.0
# 382.0
# 297.0
# 0.0
# 746.5
# 2.0
# 8.5
# 730.5
# 13.0
# 7.0
# 285.0
# 802.0
# 5.5
# 5.5
# 7.0
# 4.0
# 2.0
# 527.5
# 4.0
# 453.0
# 692.5
# 7.0
# 2.0
# 582.5
# 5.5
# 7.0
# 392.0
# 364.5
# 693.0
# 277.0
# 629.5
# 5.5
# 406.0
# 516.0
# 681.5
# 502.0
# 403.0
# 0.0
# 0.5
# 882.5
# 2.0
# 8.5
# 7.0
# 2.0
# 256.5
# 2128.0
# 25.0
# 2.0
# 8.5
# 2.0
# 4.0
# 2.0
# 1020.5
# 502.0
# 345.5
# 772.5
# 2.0
# 7.0
# 4.0
# 4.0
# 465.0
# 366.5
# 382.0
# 448.5
# 406.0
# 728.5
# 2.0
# 547.5
# 2.0
# 726.0
# 2.0
# 8.5
# 607.5
# 445.5
# 1483.5
# 114.5
# 972.0
# 7.0
# 7.0
# 2.0
# 4.0
# 490.5
# 529.5
# 20.0
# 456.5
# 387.0
# 487.5
# 537.0
# 613.0
# 497.0
# 517.0
# 593.5
# 2.0
# 17.5
# 466.5
# 669.5
# 4.0
# 393.0
# 564.5
# 851.5
# 2.0
# 5.5
# 2.0
# 627.5
# 2.0
# 5.5
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### <font color='blue'> Drawing Contours On The Real Image

# %%
img = cv2.imread('Resources/birds.jpg')

gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray_img, 127, 255, cv2.THRESH_BINARY_INV)
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

for cnt in contours:
    if cv2.contourArea(cnt) > 200: # contours area > 200        
        cv2.drawContours(img, cnt, -1, (0, 255, 0), 1)
        # image, contours area, -1, color, thickness
        
cv2.imshow('contours on image', img)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# #### Output screenshot:
# ![image-8.png](attachment:image-8.png)

# %% [markdown]
# ---

# %% [markdown]
# ### <font color='blue'> Drawing bounding box around the contours
# * we have a built a object detector to detect the object present in the image.
# * only the specific images.

# %%
img = cv2.imread('Resources/birds.jpg')

gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray_img, 127, 255, cv2.THRESH_BINARY_INV)
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

for cnt in contours:
    if cv2.contourArea(cnt) > 200:        
        x, y, w, h = cv2.boundingRect(cnt)
        cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
        
cv2.imshow('contours on image', img)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# #### Output screenshot:
# ![image-9.png](attachment:image-9.png)

# %% [markdown]
# ---
